# %% [markdown]
# <a href="https://colab.research.google.com/github/KULDEEPSONI-source/DEEPLEARNING/blob/main/Customer_Churn_Prediction_using_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
rjmanoj_credit_card_customer_churn_prediction_path = kagglehub.dataset_download('rjmanoj/credit-card-customer-churn-prediction')

print('Data source import complete.')

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv

# %%
df = pd.read_csv('/kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.drop(columns = ['RowNumber','CustomerId','Surname'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_25/627427710.py in <module>
# ----> 1 df.drop(columns = ['RowNumber','CustomerId','Surname'],inplace=True)
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['RowNumber' 'CustomerId' 'Surname'] not found in axis"

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_25/1671729091.py in <module>
# ----> 1 df = pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     888             raise TypeError("Input must be a list-like for parameter `columns`")
#     889         else:
# --> 890             data_to_encode = data[columns]
#     891
#     892         # validate prefixes and separator to avoid silently dropping cols
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Geography', 'Gender'], dtype='object')] are in the [columns]"

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2 , random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
scalar= StandardScaler()

X_train_trf = scalar.fit_transform(X_train)
X_test_trf = scalar.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
 model = Sequential()

model.add(Dense(11,activation = 'sigmoid', input_dim=11))

model.add(Dense(11,activation = 'sigmoid'))
model.add(Dense(1,activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 11)                132
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                132
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 12
# =================================================================
# Total params: 276
# Trainable params: 276
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'Adam',loss = 'binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,batch_size=50,epochs=100,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.6815 - accuracy: 0.5703 - val_loss: 0.5491 - val_accuracy: 0.7969
# Epoch 2/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5239 - accuracy: 0.7958 - val_loss: 0.5094 - val_accuracy: 0.7969
# Epoch 3/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5087 - accuracy: 0.7958 - val_loss: 0.5045 - val_accuracy: 0.7969
# Epoch 4/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5069 - accuracy: 0.7958 - val_loss: 0.5034 - val_accuracy: 0.7969
# Epoch 5/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5062 - accuracy: 0.7958 - val_loss: 0.5024 - val_accuracy: 0.7969
# Epoch 6/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5056 - accuracy: 0.7958 - val_loss: 0.5015 - val_accuracy: 0.7969
# Epoch 7/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5051 - accuracy: 0.7958 - val_loss: 0.5009 - val_accuracy: 0.7969
# Epoch 8/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5047 - accuracy: 0.7958 - val_loss: 0.5002 - val_accuracy: 0.7969
# Epoch 9/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5042 - accuracy: 0.7958 - val_loss: 0.4998 - val_accuracy: 0.7969
# Epoch 10/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5038 - accuracy: 0.7958 - val_loss: 0.4994 - val_accuracy: 0.7969
# Epoch 11/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5034 - accuracy: 0.7958 - val_loss: 0.4990 - val_accuracy: 0.7969
# Epoch 12/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5031 - accuracy: 0.7958 - val_loss: 0.4986 - val_accuracy: 0.7969
# Epoch 13/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5027 - accuracy: 0.7958 - val_loss: 0.4983 - val_accuracy: 0.7969
# Epoch 14/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5024 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 15/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 16/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5016 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 17/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5027 - accuracy: 0.7958 - val_loss: 0.4995 - val_accuracy: 0.7969
# Epoch 18/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5039 - accuracy: 0.7958 - val_loss: 0.4996 - val_accuracy: 0.7969
# Epoch 19/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5039 - accuracy: 0.7958 - val_loss: 0.4996 - val_accuracy: 0.7969
# Epoch 20/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5038 - accuracy: 0.7958 - val_loss: 0.5013 - val_accuracy: 0.7969
# Epoch 21/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5027 - accuracy: 0.7958 - val_loss: 0.4984 - val_accuracy: 0.7969
# Epoch 22/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5023 - accuracy: 0.7958 - val_loss: 0.4978 - val_accuracy: 0.7969
# Epoch 23/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 24/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 25/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5022 - accuracy: 0.7958 - val_loss: 0.4986 - val_accuracy: 0.7969
# Epoch 26/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5023 - accuracy: 0.7958 - val_loss: 0.4981 - val_accuracy: 0.7969
# Epoch 27/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 28/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5022 - accuracy: 0.7958 - val_loss: 0.4983 - val_accuracy: 0.7969
# Epoch 29/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5022 - accuracy: 0.7958 - val_loss: 0.4982 - val_accuracy: 0.7969
# Epoch 30/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5022 - accuracy: 0.7958 - val_loss: 0.4984 - val_accuracy: 0.7969
# Epoch 31/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4981 - val_accuracy: 0.7969
# Epoch 32/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 33/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5022 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 34/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 35/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4979 - val_accuracy: 0.7969
# Epoch 36/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5022 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 37/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 38/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 39/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4978 - val_accuracy: 0.7969
# Epoch 40/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5022 - accuracy: 0.7958 - val_loss: 0.4979 - val_accuracy: 0.7969
# Epoch 41/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4978 - val_accuracy: 0.7969
# Epoch 42/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4978 - val_accuracy: 0.7969
# Epoch 43/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 44/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 45/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 46/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 47/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4979 - val_accuracy: 0.7969
# Epoch 48/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 49/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 50/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 51/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 52/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4978 - val_accuracy: 0.7969
# Epoch 53/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 54/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 55/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4980 - val_accuracy: 0.7969
# Epoch 56/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 57/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4979 - val_accuracy: 0.7969
# Epoch 58/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 59/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 60/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 61/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 62/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 63/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 64/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 65/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 66/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 67/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 68/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 69/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 70/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4974 - val_accuracy: 0.7969
# Epoch 71/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 72/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 73/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 74/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 75/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 76/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 77/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 78/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 79/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 80/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 81/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4974 - val_accuracy: 0.7969
# Epoch 82/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5016 - accuracy: 0.7958 - val_loss: 0.4977 - val_accuracy: 0.7969
# Epoch 83/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 84/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4974 - val_accuracy: 0.7969
# Epoch 85/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4978 - val_accuracy: 0.7969
# Epoch 86/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 87/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4976 - val_accuracy: 0.7969
# Epoch 88/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 89/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4979 - val_accuracy: 0.7969
# Epoch 90/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 91/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4975 - val_accuracy: 0.7969
# Epoch 92/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4974 - val_accuracy: 0.7969
# Epoch 93/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4974 - val_accuracy: 0.7969
# Epoch 94/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4972 - val_accuracy: 0.7969
# Epoch 95/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5017 - accuracy: 0.7958 - val_loss: 0.4974 - val_accuracy: 0.7969
# Epoch 96/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4973 - val_accuracy: 0.7969
# Epoch 97/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.5019 - accuracy: 0.7958 - val_loss: 0.4974 - val_accuracy: 0.7969
# Epoch 98/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4973 - val_accuracy: 0.7969
# Epoch 99/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4973 - val_accuracy: 0.7969
# Epoch 100/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5018 - accuracy: 0.7958 - val_loss: 0.4972 - val_accuracy: 0.7969

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[0.1645909 ],
#        [0.24294505],
#        [0.22658649],
#        ...,
#        [0.22658649],
#        [0.24487558],
#        [0.1645909 ]], dtype=float32)

# %%
y_pred = y_pred.argmax(axis=-1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7975

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
